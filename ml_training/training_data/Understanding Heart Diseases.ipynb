# %%
import pandas as pd

# %%
chd_df = pd.read_csv('SAheart.data')

# %%
chd_df.head(5)
# Out:
#    row.names  sbp  tobacco   ldl  adiposity  famhist  typea  obesity  alcohol  \
# 0          1  160    12.00  5.73      23.11  Present     49    25.30    97.20
# 1          2  144     0.01  4.41      28.61   Absent     55    28.87     2.06
# 2          3  118     0.08  3.48      32.28  Present     52    29.14     3.81
# 3          4  170     7.50  6.41      38.03  Present     51    31.99    24.26
# 4          5  134    13.60  3.50      27.78  Present     60    25.99    57.34
#
#    age  chd
# 0   52    1
# 1   63    1
# 2   46    0
# 3   58    1
# 4   49    1

# %%
chd_df.shape
# Out:
# (462, 11)

# %%
import matplotlib.pyplot as plt
import seaborn as sn

# %%
sn.catplot(data=chd_df,x = 'famhist', kind='count')

# %%
sn.catplot(data=chd_df,x = 'famhist', kind='count', hue = 'chd')

# %%
pd.crosstab(chd_df['famhist'],chd_df['chd'],normalize='index')
# Out:
# chd             0         1
# famhist
# Absent   0.762963  0.237037
# Present  0.500000  0.500000

# %%
pd.crosstab(chd_df['age'],chd_df['chd'],normalize='index')
# Out:
# chd         0         1
# age
# 15   1.000000  0.000000
# 16   1.000000  0.000000
# 17   0.941176  0.058824
# 18   1.000000  0.000000
# 19   1.000000  0.000000
# 20   0.833333  0.166667
# 21   1.000000  0.000000
# 23   1.000000  0.000000
# 24   1.000000  0.000000
# 25   0.750000  0.250000
# 26   0.800000  0.200000
# 27   0.909091  0.090909
# 28   0.714286  0.285714
# 29   1.000000  0.000000
# 30   0.857143  0.142857
# 31   0.777778  0.222222
# 32   0.636364  0.363636
# 33   0.666667  0.333333
# 34   0.833333  0.166667
# 35   1.000000  0.000000
# 36   0.666667  0.333333
# 37   0.833333  0.166667
# 38   0.769231  0.230769
# 39   0.500000  0.500000
# 40   0.750000  0.250000
# 41   0.500000  0.500000
# 42   0.692308  0.307692
# 43   0.500000  0.500000
# 44   1.000000  0.000000
# 45   0.571429  0.428571
# 46   0.636364  0.363636
# 47   1.000000  0.000000
# 48   0.769231  0.230769
# 49   0.714286  0.285714
# 50   0.625000  0.375000
# 51   0.375000  0.625000
# 52   0.300000  0.700000
# ...

# %%
##Does age have any effect on chd

# %%
no_chd = chd_df[chd_df.chd == 0]

# %%
yes_chd = chd_df[chd_df.chd == 1]

# %%
sn.distplot(no_chd.age)

# %%
sn.distplot(yes_chd.age)

# %%
plt.hist(no_chd.age)
# Out:
# (array([49., 16., 29., 31., 23., 35., 38., 22., 27., 32.]),
#  array([15. , 19.9, 24.8, 29.7, 34.6, 39.5, 44.4, 49.3, 54.2, 59.1, 64. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(no_chd.age)
plt.hist(yes_chd.age)
# Out:
# (array([ 2.,  2.,  6.,  8., 13., 19., 11., 28., 39., 32.]),
#  array([17. , 21.7, 26.4, 31.1, 35.8, 40.5, 45.2, 49.9, 54.6, 59.3, 64. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(no_chd.age , label='No chd')
plt.hist(yes_chd.age,label='Yes Chd')
# Out:
# (array([ 2.,  2.,  6.,  8., 13., 19., 11., 28., 39., 32.]),
#  array([17. , 21.7, 26.4, 31.1, 35.8, 40.5, 45.2, 49.9, 54.6, 59.3, 64. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(no_chd.age , label='No chd')
plt.hist(yes_chd.age,label='Yes Chd')
plt.legend()

# %%
sn.distplot(no_chd.age , label='No chd')
sn.distplot(yes_chd.age,label='Yes Chd')
plt.legend()

# %%
sn.distplot(no_chd.alcohol , label='No chd')
sn.distplot(yes_chd.alcohol,label='Yes Chd')
plt.legend()

# %%
sn.distplot(no_chd.tobacco , label='No chd')
sn.distplot(yes_chd.tobacco,label='Yes Chd')
plt.legend()

# %%
plt.scatter(chd_df.age,chd_df.sbp)

# %%
sn.lmplot(data=chd_df,x='age',y='sbp')

# %%
sn.lmplot(data=chd_df,x='alcohol',y='sbp')

# %%
sn.lmplot(data=chd_df,x='tobacco',y='sbp')

# %%
chd_df.head(5)
# Out:
#    row.names  sbp  tobacco   ldl  adiposity  famhist  typea  obesity  alcohol  \
# 0          1  160    12.00  5.73      23.11  Present     49    25.30    97.20
# 1          2  144     0.01  4.41      28.61   Absent     55    28.87     2.06
# 2          3  118     0.08  3.48      32.28  Present     52    29.14     3.81
# 3          4  170     7.50  6.41      38.03  Present     51    31.99    24.26
# 4          5  134    13.60  3.50      27.78  Present     60    25.99    57.34
#
#    age  chd
# 0   52    1
# 1   63    1
# 2   46    0
# 3   58    1
# 4   49    1

# %%
sn.lmplot(data=chd_df,x='obesity',y='sbp')

# %%
chd_df.columns
# Out:
# Index(['row.names', 'sbp', 'tobacco', 'ldl', 'adiposity', 'famhist', 'typea',
#        'obesity', 'alcohol', 'age', 'chd'],
#       dtype='object')

# %%
numeral_cols = ['sbp', 'tobacco', 'ldl', 'adiposity', 'typea',
       'obesity', 'alcohol', 'age']

# %%
chd_df[numeral_cols].corr()
# Out:
#                 sbp   tobacco       ldl  adiposity     typea   obesity  \
# sbp        1.000000  0.212247  0.158296   0.356500 -0.057454  0.238067
# tobacco    0.212247  1.000000  0.158905   0.286640 -0.014608  0.124529
# ldl        0.158296  0.158905  1.000000   0.440432  0.044048  0.330506
# adiposity  0.356500  0.286640  0.440432   1.000000 -0.043144  0.716556
# typea     -0.057454 -0.014608  0.044048  -0.043144  1.000000  0.074006
# obesity    0.238067  0.124529  0.330506   0.716556  0.074006  1.000000
# alcohol    0.140096  0.200813 -0.033403   0.100330  0.039498  0.051620
# age        0.388771  0.450330  0.311799   0.625954 -0.102606  0.291777
#
#             alcohol       age
# sbp        0.140096  0.388771
# tobacco    0.200813  0.450330
# ldl       -0.033403  0.311799
# adiposity  0.100330  0.625954
# typea      0.039498 -0.102606
# obesity    0.051620  0.291777
# alcohol    1.000000  0.101125
# age        0.101125  1.000000

# %%
corr_mat = chd_df[numeral_cols].corr()

# %%
sn.heatmap()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-54-f6d12d5e7bc0> in <module>
# ----> 1 sn.heatmap()
#
# TypeError: heatmap() missing 1 required positional argument: 'data'

# %%
sn.heatmap(corr_mat,annot=True)

# %%
sn.heatmap(corr_mat,annot=True,cmap=sn.diverging_palette(200,40))

# %%
### Understading the age of people suffering from CHD

# %%
yes_chd.age.mean()
# Out:
# 50.29375

# %%
yes_chd.age.std()
# Out:
# 10.649118943684005

# %%
plt.boxplot(yes_chd.age)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x121259bd0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1260e5390>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1260e5990>],
#  'medians': [<matplotlib.lines.Line2D at 0x121259250>],
#  'fliers': [<matplotlib.lines.Line2D at 0x12127ea90>],
#  'means': []}

# %%
plt.boxplot(yes_chd.sbp)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x126203c90>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x126208710>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x126203050>],
#  'medians': [<matplotlib.lines.Line2D at 0x126203d50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x12620f690>],
#  'means': []}

# %%
box = plt.boxplot(yes_chd.age)
box.items()
# Out:
# dict_items([('whiskers', [<matplotlib.lines.Line2D object at 0x1115e8250>, <matplotlib.lines.Line2D object at 0x1115e8810>]), ('caps', [<matplotlib.lines.Line2D object at 0x1115e8d10>, <matplotlib.lines.Line2D object at 0x1115e35d0>]), ('boxes', [<matplotlib.lines.Line2D object at 0x1115e3590>]), ('medians', [<matplotlib.lines.Line2D object at 0x1115ef790>]), ('fliers', [<matplotlib.lines.Line2D object at 0x1115efc90>]), ('means', [])])

# %%
[item.get_ydata()[0] for item in box['caps']]
# Out:
# [20.0, 64.0]

# %%
[item.get_ydata()[0] for item in box['whiskers']]
# Out:
# [42.75, 59.0]
